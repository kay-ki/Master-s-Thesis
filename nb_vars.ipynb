# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython import get_ipython
from IPython.core.display import HTML
from IPython.core.interactiveshell import InteractiveShell
from publib import fix_style, set_style
from sklearn.linear_model import LinearRegression
from statsmodels.compat import lzip

# import stata_setup
# stata_setup.config('c:\Program Files\Stata17', 'mp', splash=False)
# from pystata import stata

set_style(["origin"])
# plt.rcParams.update({'font.size': 10})

df = pd.read_parquet("df_soep2.gzip")

# %%
# Convert log net income back to its actual values
df['gen_income'] = np.exp(df['gen_income'])

# %%
from scipy.stats import mannwhitneyu


def calculate_weighted_median(data, weights=None):
    data = pd.Series(data).dropna()
    if weights is None:
        weights = np.ones(len(data))
    else:
        weights = pd.Series(weights).dropna()

    ordered_data, ordered_weights = zip(*sorted(zip(data, weights)))

    midpoint = 0.5 * sum(ordered_weights)
    cum_weights = np.cumsum(ordered_weights)
    below_midpoint_index = [i for i in range(len(cum_weights)) if cum_weights[i] <= midpoint]
    median_index = max(below_midpoint_index)

    return ordered_data[median_index]

# Function will compare two dataframes by mean and median of chosen variables or will create KDE plots, depending on chosen parameter
def plot_or_table_density(df1, df2, variables_dict, custom_labels=None, show_mean=True, show_median=True, output="plot"):
    summary_stats = []
    n = len(variables_dict)
    columns = ['Variable', 'Group 1: Mean', 'Group 1: Median', 'Group 2: Mean', 'Group 2: Median']

    if custom_labels:
        if len(custom_labels) == len(columns):
            columns = custom_labels

    if output == "plot":
        fig, axs = plt.subplots(n, 2, figsize=(10, 3 * n), tight_layout=True)
        colors = ["cornflowerblue", "lightcoral"]

    for idx, (var, label) in enumerate(variables_dict.items()):
        try:
            valid_df1 = df1[var].replace([np.inf, -np.inf], np.nan).dropna()
            valid_df2 = df2[var].replace([np.inf, -np.inf], np.nan).dropna()

            if valid_df1.empty or valid_df2.empty:
                continue

# Mann-Whitney U test, adds asterisks to significant differences in means

            stat, p_value = mannwhitneyu(valid_df1, valid_df2)
            if p_value < 0.05:
                label += '*' 

            mean1, median1 = np.mean(valid_df1), np.median(valid_df1)
            mean2, median2 = np.mean(valid_df2), np.median(valid_df2)

            summary_stats.append(dict(zip(columns, [label, mean1, median1, mean2, median2])))

            if output == "plot":
                for (data, ax, color, df_label, mean, median) in zip(
                        [valid_df1, valid_df2],
                        [axs[idx, 0], axs[idx, 1]],
                        colors,
                        ["Group 1", "Group 2"],
                        [mean1, mean2],
                        [median1, median2]):

                    sns.kdeplot(data, ax=ax, fill=True, color=color, label=df_label, bw_adjust=1)

                    if show_mean:
                        ax.axvline(mean, color="k", linestyle="--", label="Mean")

                    if show_median:
                        ax.axvline(median, color="k", linestyle="-", label="Median")

                    ax.set_title(f"{label} - {df_label}")
                    ax.legend()

        except Exception as e:
            print(f"An error occurred while processing the variable '{var}': {e}")
            continue

    if output == "plot":
        plt.show()
    elif output == "table":
        summary_df = pd.DataFrame(summary_stats, columns=columns)
        display(summary_df)
        return summary_df

# List of labels
variables_dict = {
    "continent_Africa": "CONT: Africa",
    "continent_Asia": "CONT: Asia",
    "continent_Europe": "CONT: Europe",
    "continent_North_America": "CONT: N. America",
    "continent_Oceania": "CONT: Oceania",
    "continent_South_America": "CONT: S. America",
    "age": "Age",
    "bad_health": "Bad Health",
    "sex": "Female",
    "satisfaction": "Life Satisfaction",
    "german": "German Citizenship",
    "gen_income": "Net Income",
    "num_children": "Number of Children",
    "refugee": "Refugee",
    "edu_years": "Years of Education",
    "migr_age": "Age at Migration",
    "xenophobia": "Concern about Xenophobia",
    "discrimination": "Disadvantaged due to Origin",
    "dist_origin": "Distance to Origin Country",
    "feel_german": "Feeling German",
    "satisf_peers": "Life Satisfaction of Peers",
    "lang_profic": "Language Proficiency",
    "visit_germ": "Visited Germans in Last Year",
    "y_in_germany": "Years since Migration",
    "cl_friends": "Number of Close Friends",
    "lonely": "Experiencing Loneliness",
    "gen_wpartner": "Living with Legal Partner",
    "gen_seppart": "Separated from Legal Partner",
    "gen_single": "Single",
    "gen_wid_div": "Widowed or Divorced",
    "gen_vocation": "Student/in Training",
    "gen_employed": "Employed",
    "gen_retired": "Retired",
    "gen_regunempl": "Unemployed",
    "sat_work": "Satisfaction with Work",
    "sat_hhinc": "Satisfaction with Income",
    "sat_dwell": "Satisfaction with Dwelling",
    "sat_leisure": "Satisfaction with Leisure",
    "sat_family": "Satisfaction with Family Life",
    "sat_sleep": "Satisfaction with Sleep"
}

# Direct migrants and all others

df1 = df[df["migback"] != 2]
df2 = df[df["migback"] == 2]

table1 = plot_or_table_density(df1, df2, variables_dict, output='table')

# Female and male migrants

df1 = df[(df['migback'] == 2) & (df['sex'] == 1)]
df2 = df[(df['migback'] == 2) & (df['sex'] == 0)]

custom_labels = ['Variable', 'Females: Mean', 'Females: Median', 'Males: Mean', 'Males: Median']
table2 = plot_or_table_density(df1, df2, variables_dict, custom_labels=custom_labels, output="table")


latex_table1 = table1.to_latex(index=False, float_format="{:0.4f}".format)
with open('table1.tex', 'w') as file:
    file.write(latex_table1)
    
latex_table2 = table2.to_latex(index=False, float_format="{:0.4f}".format)
with open('table2.tex', 'w') as file:
    file.write(latex_table2)
# Out:
#                            Variable  Group 1: Mean  Group 1: Median  \
# 0                     CONT: Africa*       0.000000          0.00000
# 1                       CONT: Asia*       0.000000          0.00000
# 2                     CONT: Europe*       1.000000          1.00000
# 3                 CONT: N. America*       0.000000          0.00000
# 4                    CONT: Oceania*       0.000000          0.00000
# 5                 CONT: S. America*       0.000000          0.00000
# 6                              Age*      47.037181         46.00000
# 7                       Bad Health*       0.165157          0.00000
# 8                           Female*       0.527983          1.00000
# 9                Life Satisfaction*       7.134240          8.00000
# 10              German Citizenship*       0.979477          1.00000
# 11                      Net Income*     942.637833        503.00000
# 12              Number of Children*       0.831325          0.00000
# 13                         Refugee*       0.000834          0.00000
# 14              Years of Education*      12.215058         11.50000
# 15        Concern about Xenophobia*       0.734735          1.00000
# 16     Disadvantaged due to Origin*       0.012277          0.00000
# 17      Distance to Origin Country*       0.000000          0.00000
# 18                  Feeling German*       0.780075          1.00000
# 19       Life Satisfation of Peers*       7.276774          7.28185
# 20            Language Proficiency*       0.995803          1.00000
# 21    Visited Germans in Last Year*       0.941942          1.00000
# 22         Number of Close Friends*       4.245550          3.00000
# 23         Experiencing Loneliness*       3.245182          3.00000
# 24       Living with Legal Partner*       0.583081          1.00000
# 25    Seperated from Legal Partner*       0.021739          0.00000
# 26                          Single*       0.256824          0.00000
# 27             Widowed or Divorced*       0.139256          0.00000
# 28             Student/in Training*       0.029751          0.00000
# 29                        Employed*       0.524053          1.00000
# 30                         Retired*       0.171910          0.00000
# 31                      Unemployed*       0.044453          0.00000
# 32          Satisfaction with Work*       7.089204          8.00000
# 33        Satisfaction with Income*       6.548512          7.00000
# 34      Satisfaction with Dwelling*       7.804420          8.00000
# 35       Satisfaction with Leisure*       7.059560          8.00000
# 36  Satisfaction with Familiy Life*       7.894430          8.00000
# 37         Satisfaction with Sleep*       6.756454          7.00000
#
#     Group 2: Mean  Group 2: Median
# 0        0.032509         0.000000
# 1        0.403166         0.000000
# 2        0.496154         0.000000
# 3        0.009390         0.000000
# 4        0.000684         0.000000
# 5        0.008052         0.000000
# 6       42.384825        41.000000
# 7        0.172405         0.000000
# 8        0.496363         0.000000
# 9        7.201835         8.000000
# 10       0.323605         0.000000
# 11     708.258341       334.000000
# 12       1.198678         1.000000
# 13       0.204239         0.000000
# 14      10.104077        10.500000
# 15       0.668340         1.000000
# 16       0.346528         0.000000
# 17    2594.515893      2339.038906
# 18       0.397765         0.000000
# 19       6.600940         6.715218
# 20       0.808917         1.000000
# 21       0.830509         1.000000
# 22       4.309512         3.000000
# 23       3.162171         3.000000
# 24       0.700580         1.000000
# 25       0.042618         0.000000
# 26       0.175291         0.000000
# 27       0.082224         0.000000
# 28       0.023918         0.000000
# 29       0.478481         0.000000
# 30       0.083271         0.000000
# 31       0.100803         0.000000
# 32       7.095357         8.000000
# 33       6.155805         6.000000
# 34       7.239619         8.000000
# 35       6.734507         7.000000
# 36       8.146767         9.000000
# 37       6.849769         7.000000
#                            Variable  Females: Mean  Females: Median  \
# 0                     CONT: Africa*       0.025920         0.000000
# 1                       CONT: Asia*       0.376229         0.000000
# 2                     CONT: Europe*       0.527500         1.000000
# 3                  CONT: N. America       0.009843         0.000000
# 4                     CONT: Oceania       0.000710         0.000000
# 5                 CONT: S. America*       0.009292         0.000000
# 6                               Age      42.466643        40.000000
# 7                       Bad Health*       0.193123         0.000000
# 8                           Female*       1.000000         1.000000
# 9                Life Satisfaction*       7.223913         8.000000
# 10              German Citizenship*       0.356600         0.000000
# 11                      Net Income*     430.642950         1.000000
# 12              Number of Children*       1.237529         1.000000
# 13                         Refugee*       0.163239         0.000000
# 14              Years of Education*      10.075356        10.000000
# 15                Age at Migration*      24.858625        24.000000
# 16        Concern about Xenophobia*       0.696809         1.000000
# 17     Disadvantaged due to Origin*       0.335488         0.000000
# 18      Distance to Origin Country*    2586.226027      2339.038906
# 19                  Feeling German*       0.410690         0.000000
# 20       Life Satisfation of Peers*       6.625549         6.735984
# 21             Language Proficiency       0.810595         1.000000
# 22     Visited Germans in Last Year       0.832518         1.000000
# 23           Years since Migration*      16.732702        15.000000
# 24         Number of Close Friends*       3.991460         3.000000
# 25         Experiencing Loneliness*       3.074993         3.000000
# 26       Living with Legal Partner*       0.709174         1.000000
# 27    Seperated from Legal Partner*       0.039119         0.000000
# 28                          Single*       0.131869         0.000000
# 29             Widowed or Divorced*       0.120323         0.000000
# 30             Student/in Training*       0.018034         0.000000
# 31                        Employed*       0.374659         0.000000
# 32                         Retired*       0.092359         0.000000
# 33                      Unemployed*       0.090734         0.000000
# 34          Satisfaction with Work*       7.068944         8.000000
# 35        Satisfaction with Income*       6.203178         6.000000
# 36      Satisfaction with Dwelling*       7.277560         8.000000
# 37       Satisfaction with Leisure*       6.640744         7.000000
# 38  Satisfaction with Familiy Life*       8.104346         8.000000
# 39         Satisfaction with Sleep*       6.721958         7.000000
#
#     Males: Mean  Males: Median
# 0      0.039004       0.000000
# 1      0.429714       0.000000
# 2      0.465261       0.000000
# 3      0.008944       0.000000
# 4      0.000657       0.000000
# 5      0.006829       0.000000
# 6     42.304188      41.000000
# 7      0.151580       0.000000
# 8      0.000000       0.000000
# 9      7.180075       8.000000
# 10     0.291086       0.000000
# 11   981.863772     920.000000
# 12     1.159514       1.000000
# 13     0.244653       0.000000
# 14    10.132507      10.500000
# 15    25.214660      25.000000
# 16     0.640115       1.000000
# 17     0.357637       0.000000
# 18  2602.686018    2339.038906
# 19     0.383906       0.000000
# 20     6.574260       6.686894
# 21     0.807360       1.000000
# 22     0.828060       1.000000
# 23    16.504776      15.000000
# 24     4.655068       3.000000
# 25     3.257311       4.000000
# 26     0.692145       1.000000
# 27     0.046054       0.000000
# 28     0.217911       0.000000
# 29     0.044828       0.000000
# 30     0.029717       0.000000
# 31     0.580803       1.000000
# 32     0.075189       0.000000
# 33     0.110727       0.000000
# 34     7.115820       8.000000
# 35     6.104938       6.000000
# 36     7.198668       8.000000
# 37     6.834827       7.000000
# 38     8.197880       9.000000
# 39     7.003345       7.000000
# /tmp/ipykernel_2218/1342370619.py:144: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_table1 = table1.to_latex(index=False, float_format="{:0.4f}".format)
# /tmp/ipykernel_2218/1342370619.py:148: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_table2 = table2.to_latex(index=False, float_format="{:0.4f}".format)
